# %% [markdown]
# 1. What is the primary goal of Object-Oriented Programming (OOP)?

# %% [markdown]
# The primary goal of of OOP in python programming is:
# - robustness; the program should be error free with proper exception handelling.
# - Adaptibility: The program should be made such that it can last for a long time and should not need frequent changes in code.
# - Reuseability: The code should be Reuseable in other programs as a subcomponent

# %% [markdown]
# 2. What is an object in Python?

# %% [markdown]
# class objects are the object of a class it contains all the arguments and method present inside the class

# %%
class Person:
    def __init__(self,name1,last_name1):
        self.name=name1
        self.last_name=last_name1
    def __str__(self):
        return f"The name is {self.name} and last name is {self.last_name}"

per1 = Person('kartikey','pillay')    # per1 is an object of class Person
print(per1)
# Out:
# The name is kartikey and last name is pillay

# %% [markdown]
# 3. What is a class in Python?

# %% [markdown]
# Pyhton class is a blueprint, or a collection of functions (called methods in OOP) for storing information, performing specific tasks and giving necessary output. Hence they provide a structure to our overall program

# %% [markdown]
# 4. What are attributes and methods in a class?

# %% [markdown]
# - Attributes are variable holding some data within the class
# - Methods are the function using that data to perform some operation

# %%
class person:
    def __init__(self,name,age):
        self.name = name         #attributes of instance
        self.age = age
        
    def displayname(self):       #method of class 'person'
        print(f'the name is "{self.name}"')

# %%
p1 = person("kartikey",25)
print(p1.name) 
p1.displayname()
# Out:
# kartikey
# the name is "kartikey"

# %% [markdown]
# 5. What is the difference between class variables and instance variables in Python?

# %% [markdown]
# class variable are variable that are valid for whole class and class variable can be accessed by any instance variable (or method) of that class, whereas the instance variable are variable inside a particular instance and are valid only for thos instance

# %%
class Person1:
    no_name = "no name given"  # class variable

    def __init__(self, name, age):
        self.name = name  # instance variable
        self.age = age

    def displayname(self):
        if len(self.name) > 0:
            print(f'The name is "{self.name}"')
        else:
            print(Person1.no_name)  # accessing class variable using the class name

# %%
tmk = Person1(name='', age=26)
tmk.displayname()
# Out:
# no name given

# %% [markdown]
# 6. What is the purpose of the self parameter in Python class methods?

# %% [markdown]
# self acts as a pointer to constructor attributes when creating the class and allows the instance of a class object, methods of the same class to effectively use the data in those attributes

# %% [markdown]
# 7. For a library management system, you have to design the "Book" class with OOP
# principles in mind. The “Book” class will have following attributes:
# - a. title: Represents the title of the book.
# - b. author: Represents the author(s) of the book.
# - c. isbn: Represents the ISBN (International Standard Book Number) of the book.
# - d. publication_year: Represents the year of publication of the book.
# - e. available_copies: Represents the number of copies available for checkout.
#
# The class will also include the following methods:
# - a. check_out(self): Decrements the available copies by one if there are copies
# available for checkout.
# - b. return_book(self): Increments the available copies by one when a book is
# returned.
# - c. display_book_info(self): Displays the information about the book, including its
# attributes and the number of available copies.

# %%
class Book:
    def __init__(self,title,author,isbn,publication_year,available_copies):
        self.title = title
        self.author = author
        self.isbn = isbn
        if isinstance(publication_year, int):
            self.publication_year = publication_year
        else:
            raise TypeError("Publication year must be numeric value.")
            
        if isinstance(available_copies, int):
            self.available_copies = available_copies
        else:
            raise TypeError("Year must be a numeric value")
        
    def check_out(self):
        if self.available_copies > 1:
            self.available_copies=self.available_copies-1
        else:
            print("only one copy of the book is available")

    def return_book(self):
        self.available_copies=self.available_copies+1

    def display_book(self):
        print("the name of book is:",self.title)
        print("author of book is:", self.author)
        print('year of publication:',self.publication_year)
        print('')

# %%
book1 = Book("Crime and Punishment","Doestovesky","41351351",1998,5)

book1.display_book()
# Out:
# the name of book is: Crime and Punishment
# author of book is: Doestovesky
# year of publication: 1998

# %% [markdown]
# 8. For a ticket booking system, you have to design the "Ticket" class with OOP
# principles in mind. The “Ticket” class should have the following attributes:
# - a. ticket_id: Represents the unique identifier for the ticket.
# - b. event_name: Represents the name of the event.
# - c. event_date: Represents the date of the event.
# - d. venue: Represents the venue of the event.
# - e. seat_number: Represents the seat number associated with the ticket.
# - f. price: Represents the price of the ticket.
# - g. is_reserved: Represents the reservation status of the ticket.
#
# The class also includes the following methods:
#
# - a. reserve_ticket(self): Marks the ticket as reserved if it is not already reserved.
# - b. cancel_reservation(self): Cancels the reservation of the ticket if it is already
# reserved.
# - c. display_ticket_info(self): Displays the information about the ticket, including its
# attributes and reservation status.

# %%
class Ticket:
    def __init__ (self,ticket_id, event_name, event_date, venue,seat_number,price,is_reserved):
        self.ticket_id = ticket_id
        self.event_name = event_name
        self.event_date = event_date
        self.venue = venue
        self.seat_number = seat_number
        self.price = price
        self.is_reserved = is_reserved
        
    def reserve_ticket(self):
        if self.is_reserved != 'R':
            self.is_reserved = 'R'
            print("reserving the ticket")
        else: print("the ticket is already reserved")
        
    def cancel_reservation(self):
        if self.is_reserved == 'R':
            self.is_reserved = 'UR'
            print("cancelling the reserved the ticket")
        else: print("the ticket is already not reserved")
            
    def display_ticket_info(self):
        print('the details of your ticket are: ')
        print('ticket id:',self.ticket_id)
        print('event_name:',self.event_name)
        print('event_date:',self.event_date)
        print('ticket status',self.reserve_ticket)

# %%
t1 = Ticket(11,'belethparty','27/11/2023','Banglore',123,700,'R')
t1.display_ticket_info()
t1.cancel_reservation()
# Out:
# the details of your ticket are:
# ticket id: 11
# event_name: belethparty
# event_date: 27/11/2023
# ticket status <bound method Ticket.reserve_ticket of <__main__.Ticket object at 0x7d60bd87eec0>>
# cancelling the reserved the ticket

# %% [markdown]
# 9. You are creating a shopping cart for an e-commerce website. Using OOP to model
# the "ShoppingCart" functionality the class should contain following attributes and
# methods:
# - a. items: Represents the list of items in the shopping cart.
#
# The class also includes the following methods:
#
# - a. add_item(self, item): Adds an item to the shopping cart by appending it to the
# list of items.
# - b. remove_item(self, item): Removes an item from the shopping cart if it exists in
# the list.
# - c. view_cart(self): Displays the items currently present in the shopping cart.
# - d. clear_cart(self): Clears all items from the shopping cart by reassigning an
# empty list to the items attribute.

# %%
class ShoppingCart:

    def __init__(self, items=[]):
        self.items = items

    def add_item(self, item):
        self.items.append(item)
        
    def remove_item(self,item):
        if item in self.items:
            self.items.remove(item)
            print(f"the {item} is removed")
        else: print('the item is not in the cart')
        
    def view_cart(self):
        for i,v in enumerate(self.items):
            print(f"the {i+1} item is {v}")
        if len(self.items) == 0:
            print('no items in cart')
            
    def clear_cart(self):
        self.items.clear()
        self.items=[]

# %%
cart = ShoppingCart(['Apples','Oranges','tea','coffee'])
cart.add_item('banana')
cart.remove_item('tea')
cart.view_cart()
cart.clear_cart()
cart.view_cart()
# Out:
# the tea is removed
# the 1 item is Apples
# the 2 item is Oranges
# the 3 item is coffee
# the 4 item is banana
# no items in cart

# %% [markdown]
# 10. Imagine a school management system. You have to design the "Student" class using
# OOP concepts.The “Student” class has the following attributes:
# - a. name: Represents the name of the student.
# - b. age: Represents the age of the student.
# - c. grade: Represents the grade or class of the student.
# - d. student_id: Represents the unique identifier for the student.
# - e. attendance: Represents the attendance record of the student.
#
# The class should also include the following methods:
#
# - a. update_attendance(self, date, status): Updates the attendance record of the
# student for a given date with the provided status (e.g., present or absent).
# - b. get_attendance(self): Returns the attendance record of the student.
# - c. get_average_attendance(self): Calculates and returns the average
# attendance percentage of the student based on their attendance record.

# %%
class Student:
    
    def __init__(self,name,age,grade,student_id,attendance,date):
        self.name = name
        self.age = age
        self.grade = grade
        self.student_id = student_id
        self.attendance = attendance
        self.date = date
        self._attendance_dict = {}
        
    def _gen_attendance(self):
        for date, attend in zip(self.date,self.attendance):
             self._attendance_dict[date] = attend
    
    def update_attendance(self,date,attendance):
        self._gen_attendance()
        self._attendance_dict[date] = attendance
        
    def get_attendance(self):
        print(self._attendance_dict)
        
    def get_average_attendance(self):
        present_count = 0
        total_count = 0
        for attend in self._attendance_dict.values():
            if attend == 'present':
                present_count += 1
            total_count += 1
        average_attendance = present_count / total_count
        print("Average Attendance:", average_attendance)

# %%
Student1 = Student('beleth',25,'A',12345,['present','present','absent'],['13/07/23','14/7/23','15/7/23'])
Student1.update_attendance('17/8/23','present')
Student1.get_average_attendance()
Student1.get_attendance()
# Out:
# Average Attendance: 0.75
# {'13/07/23': 'present', '14/7/23': 'present', '15/7/23': 'absent', '17/8/23': 'present'}
