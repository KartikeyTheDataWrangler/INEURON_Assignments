# %% [markdown]
# 1. In Python, what is the difference between a built-in function and a user-defined function? Provide an
# example of each.

# %%
#built in function are functions already present in the python by deafult
print(len("beleth"))  
#example len, print etc

#user defined functions are functions we have to manually make 

def add(a,b):
    return a + b

add(5,6)
# Out:
# 6
# 11

# %% [markdown]
# 2. How can you pass arguments to a function in Python? Explain the difference between positional
# arguments and keyword arguments.

# %% [markdown]
# there are two ways to pass an argument in python one is using positions and other is using keywords
# - in positional method the position of our passed arguments matter
# - in keyword method the position of arguments wouldnt matter and they are passed along with an assignment operator

# %%
#example of positioal method 

def detail(name,age):
    print('hello my name is %s and age is %d'% (name,age))

detail('beleth',25)
# Out:
# hello my name is beleth and age is 25

# %%
#example of keyword method
#in below example Ive reversed the position

detail(age=16,name='lilith')
# Out:
# hello my name is lilith and age is 16

# %% [markdown]
# 3. What is the purpose of the return statement in a function? Can a function have multiple return
# statements? Explain with an example.

# %% [markdown]
# return is used to return the result of a function in python, there can be multiple return statement in python

# %%
def add(a,b,c):
    if b > a:
        return a+b
    elif b > c:
        return b+c
    elif a>b+c:
        return a+b+c

add(6,7,6), add(20,5,10),add(5,10,15)
# Out:
# (13, 35, 15)

# %% [markdown]
# 4. What are lambda functions in Python? How are they different from regular functions? Provide an
# example where a lambda function can be useful.

# %% [markdown]
# Lambda function are small, anonymous function with single expression, lambda functions are defined using lambda keyword

# %%
#lambda can be used with map
numbers = [1, 2, 3, 4, 5]

squared_numbers = list(map(lambda x: x**2, numbers))
print(squared_numbers)
# Out:
# [1, 4, 9, 16, 25]

# %% [markdown]
# 5. How does the concept of "scope" apply to functions in Python? Explain the difference between local
# scope and global scope.

# %% [markdown]
# In Python, "scope" refers to the visibility and accessibility of variables within a specific part of a program. It determines which parts of the code can access or modify a variable. Understanding scope is essential for correctly accessing variables and avoiding conflicts or unintended behavior in your code. there are two types of scopes in python local scope and global scope. local scopes variables get destroyed after a function is executed global scope variables doesnt get destroyed even if present inside a function.Global scope variable can be accessed outside of a function

# %% [markdown]
# 6. How can you use the "return" statement in a Python function to return multiple values?

# %% [markdown]
# we can use return statement using if else

# %%
def add(a,b,c):
    if b > a:
        return a+b
    elif b > c:
        return b+c
    elif a>b+c:
        return a+b+c

add(6,7,6), add(20,5,10),add(5,10,15)
# Out:
# (13, 35, 15)

# %% [markdown]
# 7. What is the difference between the "pass by value" and "pass by reference" concepts when it
# comes to function arguments in Python?

# %% [markdown]
# 8. Create a function that can intake integer or decimal value and do following operations:
#     -  a. Logarithmic function (log x)
#     - b. Exponential function (exp(x))
#     - c. Power function with base 2 (2x)
#     -  d. Square root

# %%
#answer
import math

def perform_operations(x):
    
    log_result = math.log(x)
    exp_result = math.exp(x)
    power_result = math.pow(2, x)
    sqrt_result = math.sqrt(x)
    return {
        'logarithmic': log_result,
        'exponential': exp_result,
        'power': power_result,
        'square_root': sqrt_result
    }

perform_operations(4)
# Out:
# {'logarithmic': 1.3862943611198906,
#  'exponential': 54.598150033144236,
#  'power': 16.0,
#  'square_root': 2.0}

# %% [markdown]
# 9. Create a function that takes a full name as an argument and returns first name and last name.

# %%
def name_splitter(fullname):
    fn,ln = fullname.split(' ')
    print('first name is: ',fn)
    print('last name is: ',ln)

name_splitter("kartikey pillay")
# Out:
# first name is:  kartikey
# last name is:  pillay
