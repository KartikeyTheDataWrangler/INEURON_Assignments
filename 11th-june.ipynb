# %% [markdown]
# 1. What is a lambda function in Python, and how does it differ from a regular function?

# %% [markdown]
#  a lambda function is a small, anonymous function that can be defined without a name. It doesnt require a def

# %% [markdown]
# 2. Can a lambda function in Python have multiple arguments? If yes, how can you define and use
# them?

# %% [markdown]
# yes a lambda function can have multiple arguments example

# %%
add = lambda x,y,z: x+y if x>y else x+y+z

add(2,4,6),add(4,2,5)
# Out:
# (12, 6)

# %% [markdown]
# 3. How are lambda functions typically used in Python? Provide an example use case.

# %%
#lambda functions are used with map,filter,reduce etc

#lambda can be used with map
numbers = [1, 2, 3, 4, 5]

squared_numbers = list(map(lambda x: x**2, numbers))
squared_numbers
# Out:
# [1, 4, 9, 16, 25]

# %% [markdown]
# 4. What are the advantages and limitations of lambda functions compared to regular functions in
# Python?

# %% [markdown]
# - Advantages :
#   small syntax, Anonymous doesnt require a name, can be assigned to variables or passed as an argument.
# - limitations: if else then not possible to do easily, harder readability, difficult to understand,defined with a single expression no commenting or documentation possible

# %% [markdown]
# 5. Are lambda functions in Python able to access variables defined outside of their own scope?
# Explain with an example.

# %%
#yes they can example
#consider global variables 
x = 10
y = 20
def prntz(a,b):  
    z = lambda a,b: a+b
    y =  z(a,b)          #using variables a,b
    return y                       
    
prntz(x,y)          #passing variables x,y outside of my lambda function using positions
# Out:
# 30

# %% [markdown]
# 6. Write a lambda function to calculate the square of a given number.

# %%
z = lambda x: x**2
z(23)
# Out:
# 529

# %% [markdown]
# 7. Create a lambda function to find the maximum value in a list of integers.

# %%
y = [5,10,15,50,100]
#make a lambda function

some_func = lambda x: max(max(x) for i in x)
some_func(y)
# Out:
# 100

# %% [markdown]
# 8. Implement a lambda function to filter out all the even numbers from a list of integers.

# %%
#here is a example code

numbers = [661,846,312,5486,12,5468,32134311,4596]

even_no = list(filter(lambda x: x%2==0, numbers))
even_no
# Out:
# [846, 312, 5486, 12, 5468, 4596]

# %% [markdown]
# 9. Write a lambda function to sort a list of strings in ascending order based on the length of each
# string.

# %%
strings = ["helo", "banana", "beleth", "date", "speakers"]

sorted_strings = sorted(strings, key=lambda s: len(s))

sorted_strings
# Out:
# ['helo', 'date', 'banana', 'beleth', 'speakers']

# %% [markdown]
# 10. Create a lambda function that takes two lists as input and returns a new list containing the
# common elements between the two lists.

# %%
x = ['x', 'y', 'z', 'a', 'b', 'c']
y = ['a', 'b', 'c', 'x', 'e', 'f', 'g']

some_func = lambda x, y: list(set([i for i in x for j in y if i == j]))

fl = input("first list seperated by space").split(' ')
sl = input("second list seperated by space").split(' ')

some_func(fl, sl)
# Out:
# first list seperated by space aa bb cc a b c
# second list seperated by space ss aa bb a a a b b b c c
# ['c', 'aa', 'a', 'bb', 'b']

# %% [markdown]
# 11. Write a recursive function to calculate the factorial of a given positive integer

# %%
def factorial(n):
    if n == 0 or n == 1:
        return 1
    else:
        return n * factorial(n - 1)

factorial(20)
# Out:
# 2432902008176640000

# %% [markdown]
# 12. Implement a recursive function to compute the nth Fibonacci number.

# %%
def my_fibonacci(n):
    if n <= 0:
        return 0
    elif n == 1:
        return 1
    else:
        return my_fibonacci(n-1) + my_fibonacci(n-2)

my_fibonacci(3)
# Out:
# 2

# %% [markdown]
# 13. Create a recursive function to find the sum of all the elements in a given list.

# %%
def rec_sum(lst):
    if len(lst) == 0:
        return 0
    else:
        return lst[0] + rec_sum(lst[1:])

l = [1, 2, 3, 4, 5, 6]
rec_sum(l)
# Out:
# 21

# %% [markdown]
# 14. Write a recursive function to determine whether a given string is a palindrome

# %%
def is_palindrome(string):
    if len(string) <= 1:
        return True
    elif string[0] != string[-1]:
        return False
    else:
        return is_palindrome(string[1:-1])

# Example usage:
is_palindrome("radar")  , is_palindrome("beleth")
# Out:
# (True, False)

# %% [markdown]
# 15. Implement a recursive function to find the greatest common divisor (GCD) of two positive integers.

# %%
def gcd(a, b):
    if b == 0:
        return a
    else:
        return gcd(b, a % b)

gcd(15,50)
# Out:
# 5
